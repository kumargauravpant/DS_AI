# %% [markdown]
# ## Probability distribution implementations using python

# %%
# for inline plots in jupyter
# %matplotlib inline
# import matplotlib
import matplotlib.pyplot as plt
# for latex equations
from IPython.display import Math, Latex
# for displaying images
from IPython.display import Image
# import seaborn
import seaborn as sns
# settings for seaborn plotting style
sns.set(color_codes=True)
# setting for seaborn plotsize
sns.set(rc={'figure.figsize':(5,5)})
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %% [markdown]
# ## 1. Uniform Distribution
#
# Perhaps one of the simplest and useful distribution is the uniform distribution. The probability distribution of the continuous uniform distribution is:
#
# ![image.png](attachment:image.png)
#
# Since any interval of numbers of equal width has an equal probability of being observed, the curve discribing the distribution is a ractangle, with constant hight across the interval and 0 hight elsewhere. Since the area under the curve must be equal to 1, the length of the interval determines the hight of the curve. The following figure shows a uniform distribution in interval (a,b). Notice since the area needs to be 1. The hight is set to 1/(b-a).

# %%
# import uniform distribution
from scipy.stats import uniform
# random number form uniform distribution
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc=start, scale=width)
ax = sns.distplot(data_uniform, 
                 bins = 100,
                 kde=True,
                 color='green',
                 hist_kws={'linewidth': 15, 'alpha': 1})
ax.set(xlabel='Uniform Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Uniform Distribution')]

# %% [markdown]
# ## 2. Normal Distribution
#
# Normal distribution, also known as Gaussian distribution, is ubiquitous in Data Science. You will encounter it at many places espacially in topics of statistical inference. It is one of the assumptions of many data science algorithms too.
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm
# generate random numbers from N(0,1)
data_normal = norm.rvs(size=10000, loc=0, scale=1)
ax = sns.distplot(data_normal,
                 bins = 100,
                 kde = True,
                 color = 'skyblue',
                 hist_kws = {'linewidth': 15, 'alpha': 1})
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# alternative code
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 0
variance = 100
sigma = math.sqrt(variance) # sigma is standard diviation
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
x1 = np.linspace(mu - 4*5, mu + 4*5, 100)
x2 = np.linspace(mu - 4*1, mu + 4*1, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.plot(x1, stats.norm.pdf(x1, mu, 5))
plt.plot(x2, stats.norm.pdf(x2, mu, 1))

plt.show()

# %% [markdown]
# ### 3. Gamma Distribution
#
# The gamma distribution is a two-parameter family of continuous probability distributions. While it is used rarely in its raw form but other popularly used distributions like exponential, chi-squared, erland distribution are special case of the gamma distribution.
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(a=5, size=10000)
ax = sns.distplot(data_gamma,
                 bins = 100,
                 kde = True,
                 color = 'skyblue',
                 hist_kws = {'linewidth': 15, 'alpha': 1})
ax.set(xlabel='Gamma Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Gamma Distribution')]

# %% [markdown]
# ### 4. Exponential Distribution
#
# The exponential distribution describes the time between events in a Poisson point process i.e. a process in which events occur continuously and independently at a constant average rate.
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1, loc=0, size=1000)
ax = sns.distplot(data_expon,
                 bins = 100,
                 kde = True,
                 color = 'red',
                 hist_kws = {'linewidth': 20, 'alpha': 1})
ax.set(xlabel='Exponential Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Exponential Distribution')]

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2,5,10000)
l = 1
y = np.asarray(list(map(lambda a: l*np.exp(-l*a) if a >= 0 else 0,x)))
plt.figure()
plt.plot(x,y)
plt.show()

# %%
x = [1,2,-3,4]
y = map(lambda a: np.exp(a) if a > 0 else 0,x)
a = np.asarray(list(a for a in y))
a
# Out:
# array([ 2.71828183,  7.3890561 ,  0.        , 54.59815003])

# %% [markdown]
# ### 5. Poisson Distribution
#
# Poisson random variable is typically used to model the number of times an event happened in a time inteval. For example, the number of users visited on a website in an interval can be thought of a Poisson process. Poisson distribution is described in terms of the rate (μ) at which the event happen. An event can occur 0,1,2,... times in an interval. The average number of events in an interval is designated by λ (lambda). Lambda is the event rate, also called the rate parameter. The probability of observing k events in an interval is given by the equation:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)
ax = sns.distplot(data_poisson,
                 bins = 30,
                 kde = False,
                 color = 'red',
                 hist_kws = {'linewidth': 15, 'alpha': 1})
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson Distribution')]

# %% [markdown]
# ### 6. Binomial Distribution
#
# A distribution where only 2 outcomes are possible success or failure, gain or loss, win or lose and where the probability of success and failure is same for all the trials is called a Binomial Distribution. The outcomes need not to be equally likely, and each trial is independent of each other. The parameters of a Binomial distributio are n and p where n is the total number of trials and p is the probability of success in each trial. Its probability distribution function is given by
#
# ![image.png](attachment:image.png)

# %% [markdown]
# where,
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=20, p=0.8, size=10000)
ax = sns.distplot(data_binom,
                 bins = 30,
                 kde = False,
                 color = 'red',
                 hist_kws = {'linewidth': 15, 'alpha': 1})
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson Distribution')]
